# %%
import pandas as pd
import datetime as dt

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ## Load General Stats

# %%
endpoint = 'https://www.sports-reference.com/cfb/years/2019-standings.html'

# %%
def get_full

# %%
results = pd.read_html(endpoint)

# %%
import requests

# %%
res = requests.get(endpoint)

# %%
def get_school_name(line):
    school = line.replace("b''","")
    return(school)

# %%
for line in res.iter_lines():
    line = str(line)
    
    school = get_school_name(line)
    print(school)
    
    #if "school_name" in line:
        #print(line)
# Out:
# b'<!DOCTYPE html>'
# b'<html data-version="klecko-" data-root="/home/cfb/build" itemscope itemtype="https://schema.org/WebSite" lang="en" class="no-js" >'
# b'<head>'
# b'    <meta charset="utf-8">'
# b'    <meta http-equiv="x-ua-compatible" content="ie=edge">'
# b'    <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=2.0" />'
# b'    <link rel="dns-prefetch" href="https://d2p3bygnnzw9w3.cloudfront.net/req/201908281" />'
#
# b'<!-- no:cookie fast load the css.           -->'
# b'<link rel="preconnect" href="https://d2p3bygnnzw9w3.cloudfront.net" crossorigin>'
# b'<link rel="preconnect" href="https://d17lgqwvsissft.cloudfront.net" crossorigin>'
# ...
